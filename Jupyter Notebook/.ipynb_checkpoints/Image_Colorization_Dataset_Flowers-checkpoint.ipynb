# %% [markdown]
# In this notebook, we will be implementing the approach of Deep Kolarization as described in research paper https://arxiv.org/pdf/1712.03400.pdf

# %%
#Import block

import torch
import torch.nn as nn
from torch.utils.data import Dataset

from torchvision.utils import save_image

import numpy as np

# %matplotlib inline

import matplotlib.pyplot as plt

import glob
import os
import pathlib

from PIL import Image
from skimage import color

from random import shuffle

import torch.optim as optim

import gc

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
local_path = '/content/data'
local_path_test = '/content/test_data'
global_path = '/content/drive/My Drive/Machine Learning - Google Colab/Flower Dataset/ML_Save_Data'
image_format = 'jpg'
image_size = 256

# %%
class CustomDataset(Dataset):
    def __init__(self, path, image_size, image_format = 'png'):
        
        self.root = path
        self.image_size = image_size
        
        path_loc = pathlib.Path(path)
        if(not path_loc.exists()):
            raise Exception('The path provided is incorrect!')
        
        searchstring = os.path.join(path,'*.'+image_format)
        list_of_images = glob.glob(searchstring)
        
        self.image_paths = list_of_images
    
    def __getitem__(self, index):
        file_path = self.image_paths[index]
        img =  self.load_image(file_path)
        img = img.resize((self.image_size, self.image_size))
        img_np = np.array(img)
        
        #Scale the values to range -1 to 1
        img_np = (img_np - 127.5)/127.5
        
        lab_img = color.rgb2lab(img)
        
        img_np = np.transpose(img_np,(2,0,1))
        lab_img = np.transpose(lab_img, (2,0,1))
        
        img_l = lab_img[0,:,:]/100
        size = img_l.shape
        
        return (torch.DoubleTensor(img_l).view(-1,size[0],size[1]), torch.DoubleTensor(img_np))
        
    def __len__(self):
        return len(self.image_paths)
    
    def load_image(self, file_path):
        with open(file_path,'rb') as file:
            with Image.open(file) as img:
                return img.convert('RGB')
    
    def __str__(self):
        return 'Dataset details are - \nRoot Location : {}\nImage Size : {}\nSize : {}\nTransforms : ToTensor and Normalize (RGB Image from -1 to 1 and Grayscale Image from 0 to 1)'.format(self.root,self.image_size, self.__len__())

# %%
path = global_path
path = local_path

# %%
# -*- coding: utf-8 -*-

import torch
from random import shuffle

class Dataloader:
    def __init__(self, path, image_size, batch_size = 16, image_format = 'png', validation_required = (False, 0.2)):
        self.path = path
        self.image_size = image_size
        self.image_format = image_format
        self.validation_req = validation_required
        self.batch_size = batch_size
    
    def get_data_loader(self):
        dataset = CustomDataset(self.path, self.image_size, self.image_format)
        print(dataset)
        size = len(dataset)
        
        train_index = list(range(size))
        valid_index = []
        
        if self.validation_req[0]:
            train_size = int(size*(1- self.validation_req[1]))
            indexes = list(range(size))
            shuffle(indexes)
            train_index = indexes[0:train_size]
            valid_index = indexes[train_size:]
        
        train_sampler = torch.utils.data.SubsetRandomSampler(train_index)
        valid_sampler = torch.utils.data.SubsetRandomSampler(valid_index)
        
        trainloader = None
        validloader = None
        if (len(valid_index) == 0):
            trainloader = torch.utils.data.DataLoader(dataset, shuffle= True, batch_size= self.batch_size)
        else:
            trainloader = torch.utils.data.DataLoader(dataset, sampler= train_sampler, batch_size= self.batch_size)
            validloader = torch.utils.data.DataLoader(dataset, sampler= valid_sampler, batch_size= self.batch_size)
        
        return (trainloader, validloader)

# %%
loader = Dataloader(path, image_size, image_format= image_format )
trainloader, validloader = loader.get_data_loader()
# Out:
# Dataset details are -
# Root Location : /content/data
# Image Size : 256
# Size : 1354
# Transforms : ToTensor and Normalize (RGB Image from -1 to 1 and Grayscale Image from 0 to 1)

# %%
test_loader = Dataloader(local_path_test, image_size, image_format= image_format )
test_trainloader, test_validloader = test_loader.get_data_loader()
# Out:
# Dataset details are -
# Root Location : /content/test_data
# Image Size : 256
# Size : 28
# Transforms : ToTensor and Normalize (RGB Image from -1 to 1 and Grayscale Image from 0 to 1)

# %%
plt.imshow(next(iter(trainloader))[0][5][0],cmap='gray')

# %% [markdown]
# # Data Loading has been done!

# %%
class Discriminator(nn.Module):
    def __init__(self, image_size = 224, leaky_relu = 0.2):
        
        super(Discriminator, self).__init__()
        
        self.leaky_relu = nn.LeakyReLU(leaky_relu)
        self.sigmoid = nn.Sigmoid()
        
        #Considering input to be 224
        self.layer_1 = nn.Conv2d(3, 32, 4, padding= 1, stride= 2)
        self.layer_1_bn = nn.BatchNorm2d(32)
        #Output size is batch_size X 32 X 112 X 112
        
        self.layer_2 = nn.Conv2d(32, 64, 4, padding= 1, stride= 2)
        self.layer_2_bn = nn.BatchNorm2d(64)
        #Output size is batch_size X 64 X 56 X 56
        
        self.layer_3 = nn.Conv2d(64, 128, 4, padding= 1, stride= 2)
        self.layer_3_bn = nn.BatchNorm2d(128)
        #Output size is batch_size X 128 X 28 X 28
        
        self.layer_4 = nn.Conv2d(128, 256, 4, padding= 1, stride= 2)
        self.layer_4_bn = nn.BatchNorm2d(256)
        #Output size is batch_size X 256 X 14 X 14
        
        self.layer_5 = nn.Conv2d(256, 512, 4, padding= 1, stride= 2)
        self.layer_5_bn = nn.BatchNorm2d(512)
        #Output size is batch_size X 512 X 7 X 7
        
        self.layer_6 = nn.Conv2d(512,1, int(image_size/32), padding= 0, stride= 1)
        
        self._initialize_weights()
    
    def forward(self, x):
        #Considering x to be of shape (batch_size X 3 X image_size X image_size)
        x = self.leaky_relu(self.layer_1_bn(self.layer_1(x)))
        
        x = self.leaky_relu(self.layer_2_bn(self.layer_2(x)))
        
        x = self.leaky_relu(self.layer_3_bn(self.layer_3(x)))
        
        x = self.leaky_relu(self.layer_4_bn(self.layer_4(x)))
        
        x = self.leaky_relu(self.layer_5_bn(self.layer_5(x)))
        
        x = self.sigmoid(self.layer_6(x))
        
        return x
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.BatchNorm2d):
                nn.init.normal_(m.weight.data, std= 0.02)
                nn.init.constant_(m.bias.data, 0)

# %%
class Generator(nn.Module):
    def __init__(self, image_size = 224):
        super(Generator, self).__init__()
        
        self.tanh = nn.Tanh()
        self.relu = nn.ReLU()
        
        #Input is of shape(1 X 1 X image_size X image_size)
        self.layer_1 = nn.Conv2d(1,64, 4, padding= 1, stride= 2)
        self.layer_1_bn = nn.BatchNorm2d(64)
        #Output is of shape (1 X 64 X 112 X 112)
        
        self.layer_2 = nn.Conv2d(64,128, 4, padding= 1, stride= 2)
        self.layer_2_bn = nn.BatchNorm2d(128)
        #Output is of shape (1 X 64 X 56 X 56)
        
        self.layer_3 = nn.Conv2d(128,256, 4, padding= 1, stride= 2)
        self.layer_3_bn = nn.BatchNorm2d(256)
        #Output is of shape (1 X 64 X 28 X 28)
        
        self.layer_4 = nn.Conv2d(256,512, 4, padding= 1, stride= 2)
        self.layer_4_bn = nn.BatchNorm2d(512)
        #Output is of shape (1 X 64 X 14 X 14)
        
        self.layer_5 = nn.Conv2d(512,512, 4, padding= 1, stride= 2)
        self.layer_5_bn = nn.BatchNorm2d(512)
        #Output is of shape (1 X 64 X 7 X 7)
        
        self.layer_6 = nn.ConvTranspose2d(512, 512, 4, padding= 1, stride= 2)
        self.layer_6_bn = nn.BatchNorm2d(512)
        #Ouput shape 14 X 14
        
        self.layer_7 = nn.ConvTranspose2d(512, 256, 4, padding= 1, stride= 2)
        self.layer_7_bn = nn.BatchNorm2d(256)
        #Ouput shape 28 X 28
        
        self.layer_8 = nn.ConvTranspose2d(256, 128, 4, padding= 1, stride= 2)
        self.layer_8_bn = nn.BatchNorm2d(128)
        #Output shape 56 X 56
        
        self.layer_9 = nn.ConvTranspose2d(128, 64, 4, padding= 1, stride= 2)
        self.layer_9_bn = nn.BatchNorm2d(64)
        #Ouput shape 112 X 112
        
        self.layer_10 = nn.ConvTranspose2d(64, 3, 4, padding= 1, stride= 2)
        #Output shape is 224 X 224
        
        self._initialize_weights()
    
    def forward(self, x):
        
        x = self.relu(self.layer_1_bn(self.layer_1(x)))
        store_1 = x
        
        x = self.relu(self.layer_2_bn(self.layer_2(x)))
        store_2 = x
        
        x = self.relu(self.layer_3_bn(self.layer_3(x)))
        store_3 = x
        
        x = self.relu(self.layer_4_bn(self.layer_4(x)))
        store_4 = x
        
        x = self.relu(self.layer_5_bn(self.layer_5(x)))
        
        x = self.relu(self.layer_6_bn(self.layer_6(x)))
        x += store_4
        
        x = self.relu(self.layer_7_bn(self.layer_7(x)))
        x += store_3
        
        x = self.relu(self.layer_8_bn(self.layer_8(x)))
        x += store_2
        
        x = self.relu(self.layer_9_bn(self.layer_9(x)))
        x += store_1
        
        x = self.tanh(self.layer_10(x))
        
        return x
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d) or isinstance(m, nn.BatchNorm2d):
                nn.init.normal_(m.weight.data, std= 0.02)
                nn.init.constant_(m.bias.data,0)

# %%
class Model:
    def __init__(self, base_path = '', epochs = 10, learning_rate = 0.0002, image_size = 224, leaky_relu = 0.2, betas = (0.5,0.999), lamda = 100, image_format = 'png'):
        self.image_size = image_size
        self.leaky_relu_threshold = leaky_relu
        
        self.epochs = epochs
        self.lr = learning_rate
        self.betas = betas
        self.lamda = lamda
        self.base_path = base_path
        self.image_format = image_format
        self.count = 1
        
        self.gen = None
        self.dis = None
        
        self.gen_optim = None
        self.dis_optim = None
        
        self.device = self.get_device()
    
    def get_device(self):
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print('Using device:', device)
        
        #Additional Info when using cuda
        if device.type == 'cuda':
            print(torch.cuda.get_device_name(0))
            print('Memory Usage -')
            print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
            print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
            return device
        else:
            return None
    
    def initialize_model(self, model_type = 'unet'):
        
        if(model_type == 'unet'):
            self.gen = Generator(image_size= self.image_size)
            self.dis = Discriminator(image_size= self.image_size, leaky_relu= self.leaky_relu_threshold)
            
            self.gen.double()
            self.dis.double()
            
            if(self.device != None):
                self.gen.cuda()
                self.dis.cuda()
            
            self.gen_optim = optim.Adam(self.gen.parameters(), lr= self.lr, betas= self.betas)
            self.dis_optim = optim.Adam(self.dis.parameters(), lr= self.lr, betas= self.betas)
            print('Model Initialized !')
    
    def train_model(self, trainloader, save_model = (False, 25), display_test_image = (False, None, 25)):
        
        mean_loss = nn.BCELoss()
        l1_loss = nn.L1Loss()
        
        self.gen.train()
        self.dis.train()
        
        gen_loss = []
        dis_loss = []
        
        iterations = 1
        
        sample_img_test = None
        if display_test_image[0]:
            gray_test_images, rgb_test_images = next(iter(display_test_image[1]))
            sample_img_test = gray_test_images[0].view(1,1,self.image_size, self.image_size)
            if self.device != None:
                sample_img_test = sample_img_test.cuda()
                save_image((rgb_test_images[0].detach().cpu()+1)/2, '{}/real_img.{}'.format(self.base_path, self.image_format))
        
        running_gen_loss = 0
        running_dis_loss = 0

        for i in range(self.epochs):
            
            for gray_img, real_img in trainloader:
                
                batch_size = len(gray_img)
                zero_label = torch.zeros(batch_size, dtype = torch.double)
                one_label = torch.ones(batch_size, dtype = torch.double)
  
                if self.device != None:
                    gray_img = gray_img.cuda()
                    real_img = real_img.cuda()
                    zero_label = zero_label.cuda()
                    one_label = one_label.cuda()
                    
                #Discriminator loss
                self.dis_optim.zero_grad()
                fake_img = self.gen(gray_img)
                
                dis_real_loss = mean_loss(self.dis(real_img), one_label)
                dis_fake_loss = mean_loss(self.dis(fake_img), zero_label)
                    
                total_dis_loss = dis_fake_loss + dis_real_loss
                total_dis_loss.backward()
                self.dis_optim.step()
                    
                #Generator loss
                self.gen_optim.zero_grad()
                
                fake_img = self.gen(gray_img)
                gen_adv_loss = mean_loss(self.dis(fake_img),one_label)
                gen_l1_loss = l1_loss(fake_img.view(batch_size, -1), real_img.view(batch_size, -1))
            
                total_gen_loss = gen_adv_loss + self.lamda*gen_l1_loss
                total_gen_loss.backward()
                self.gen_optim.step()
                    
                running_dis_loss += total_dis_loss.item()
                running_gen_loss += total_gen_loss.item()                                
                
                if(display_test_image[0] and iterations % display_test_image[2] == 0):
                    self.gen.eval()
                    out_result = self.gen(sample_img_test)
                    out_result = out_result.detach().cpu()
                    out_result = (out_result[0] + 1)/2
                    save_image(out_result,'{}/iteration_{}.{}'.format(self.base_path, iterations, self.image_format))
                    self.gen.train()
                iterations += 1
                
                if(save_model[0] and iterations % save_model[1] == 0):
                    self.save_checkpoint('checkpoint_iter_{}'.format(iterations), 'unet')
                
                if (iterations % 20 == 0):
                    running_gen_loss /= 20.0
                    running_dis_loss /= 20.0
                    print('Losses after iteration : {} : Discriminator Loss : {} and Generator Loss : {}'.format(iterations, running_dis_loss, running_gen_loss))
                    gen_loss.append(running_gen_loss)
                    dis_loss.append(running_dis_loss)
                    running_gen_loss = 0
                    running_dis_loss = 0
        
        plt.plot(gen_loss, label = 'Generator Loss')
        plt.plot(dis_loss, label = 'Discriminator Loss')
        plt.legend()
        plt.show()
        
        return (gen_loss, dis_loss)
    
    def evaluate_model(self, loader, save_filename, no_of_images = 1):
        
        counter_images_generated = 0
        while(counter_images_generated < no_of_images):
          gray, rgb = next(iter(loader))
          test_img = gray[5]
          real_img = rgb[5]
          
          if(self.device != None):
              test_img = test_img.cuda()
          
          if(self.gen == None or self.dis == None):
              raise Exception('Model has not been initialized!')
          
          filename = '{}/{}_{}.{}'.format(self.base_path, save_filename, self.count, self.image_format)
          real_filename = '{}/{}_{}_real.{}'.format(self.base_path, save_filename, self.count, self.image_format)
          real_gray_filename = '{}/{}_{}_real_gray.{}'.format(self.base_path, save_filename, self.count, self.image_format)
          self.count += 1
          
          self.gen.eval()
          test_img = test_img.view(1,1,self.image_size, self.image_size)
          out = self.gen(test_img)
          out = out.detach().cpu()
          out = (out+1)/2
          save_image(out, filename)
          
          gray_img = gray[5].detach().cpu()
          save_image(gray_img, real_gray_filename)

          real_img = (real_img.detach().cpu() +1)/2
          save_image(real_img, real_filename)

          counter_images_generated +=1
    
    def change_params(self, epochs = None, learning_rate = None, leaky_relu = None, betas = None, lamda = None):
        if(epochs != None):
            self.epochs = epochs
            print('Changed the number of epochs!')
        if(learning_rate != None):
            self.lr = learning_rate
            print('Changed the learning rate!')
        if(leaky_relu != None):
            self.leaky_relu_threshold = leaky_relu
            print('Changed the threshold for leaky relu!')
        if(betas != None):
            self.betas = betas
            print('Changed the betas for Adams Optimizer!')
        if(betas != None or learning_rate != None):
            self.gen_optim = optim.Adam(self.gen.parameters(), lr= self.lr, betas= self.betas)
            self.dis_optim = optim.Adam(self.dis.parameters(), lr= self.lr, betas= self.betas)
            
        if(lamda != None):
            self.lamda = lamda
            print('Lamda value has been changed!')
    
    def save_checkpoint(self, filename, model_type = 'unet'):
        if(self.gen == None or self.dis == None):
            raise Exception('The model has not been initialized and hence cannot be saved !')
        
        filename = '{}/checkpoints/{}.pth'.format(self.base_path, filename)
        save_dict = {'model_type': model_type, 'dis_dict':self.dis.state_dict(), 'gen_dict': self.gen.state_dict(), 'lr': self.lr,
                    'epochs' : self.epochs, 'betas': self.betas, 'image_size':self.image_size, 
                     'leaky_relu_thresh' : self.leaky_relu_threshold, 'lamda' : self.lamda, 'base_path': self.base_path, 
                     'count' : self.count, 'image_format': self.image_format}
        
        torch.save(save_dict, filename)
        
        print('The model checkpoint has been saved !')
    
    def load_checkpoint(self, filename):
        filename = '{}/checkpoints/{}.pth'.format(self.base_path, filename)
        if(not pathlib.Path(filename).exists()):
            raise Exception('This checkpoint does not exist!')
        
        self.gen = None
        self.dis = None
        
        save_dict = torch.load(filename)
        
        self.betas = save_dict['betas']
        self.image_size = save_dict['image_size']
        self.epochs = save_dict['epochs']
        self.leaky_relu_threshold = save_dict['leaky_relu_thresh']
        self.lamda = save_dict['lamda']
        self.lr = save_dict['lr']
        self.base_path = save_dict['base_path']
        self.count = save_dict['count']
        self.image_format = save_dict['image_format']
        self.device = self.get_device()
        
        self.initialize_model(model_type= save_dict['model_type'])
        
        self.gen.load_state_dict(save_dict['gen_dict'])
        self.dis.load_state_dict(save_dict['dis_dict'])
        
        print('The model checkpoint has been restored')

# %%
model = Model(base_path = global_path, image_size= image_size, image_format = image_format)
# Out:
# Using device: cuda
# Tesla P100-PCIE-16GB
# Memory Usage -
# Allocated: 0.1 GB
# Cached:    0.3 GB

# %%
model.initialize_model()
# Out:
# Model Initialized !
# Changed the number of epochs!
# Changed the learning rate!
# Lamda value has been changed!

# %%
model.change_params(epochs=55)
model.change_params(learning_rate = 0.0001)
model.change_params(lamda = 100)
# Out:
# Changed the number of epochs!
# Changed the learning rate!
# Lamda value has been changed!

# %%
model.load_checkpoint('checkpoint_iter_8600')
# Out:
# Using device: cuda
# Tesla P100-PCIE-16GB
# Memory Usage -
# Allocated: 0.1 GB
# Cached:    0.3 GB
# Model Initialized !
# The model checkpoint has been restored

# %%
model.evaluate_model(test_trainloader, 'test', 28)

# %%
model.train_model(trainloader, save_model= (True, 100), display_test_image=(True, trainloader, 20))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([16, 1, 1, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# Losses after iteration : 20 : Discriminator Loss : 1.1385328290710433 and Generator Loss : 7.983951245908706
# Losses after iteration : 40 : Discriminator Loss : 1.1791269560896362 and Generator Loss : 8.842950530540321
# Losses after iteration : 60 : Discriminator Loss : 1.141373723546566 and Generator Loss : 8.864234235289034
# Losses after iteration : 80 : Discriminator Loss : 1.1533667138655503 and Generator Loss : 8.849239966038054
# The model checkpoint has been saved !
# Losses after iteration : 100 : Discriminator Loss : 1.1529518249174844 and Generator Loss : 8.624198818874515
# Losses after iteration : 120 : Discriminator Loss : 1.136410241502977 and Generator Loss : 8.854959778428116
# Losses after iteration : 140 : Discriminator Loss : 1.2213811358704876 and Generator Loss : 8.379893908203428
# Losses after iteration : 160 : Discriminator Loss : 1.2154852408543102 and Generator Loss : 8.891314742529246
# Losses after iteration : 180 : Discriminator Loss : 1.1186936115611217 and Generator Loss : 8.90380472844917
# The model checkpoint has been saved !
# Losses after iteration : 200 : Discriminator Loss : 1.2068840870363737 and Generator Loss : 8.726989512398168
# Losses after iteration : 220 : Discriminator Loss : 1.070244209835716 and Generator Loss : 8.725664562005345
# Losses after iteration : 240 : Discriminator Loss : 1.1886359660108128 and Generator Loss : 8.603702788893841
# Losses after iteration : 260 : Discriminator Loss : 1.2232350206907143 and Generator Loss : 8.169645918125257
# Losses after iteration : 280 : Discriminator Loss : 1.2149549029516928 and Generator Loss : 8.575522025439897
# The model checkpoint has been saved !
# Losses after iteration : 300 : Discriminator Loss : 1.2426636477509667 and Generator Loss : 8.223437585831816
# Losses after iteration : 320 : Discriminator Loss : 1.1446380844016246 and Generator Loss : 8.295579713243173
# Losses after iteration : 340 : Discriminator Loss : 1.0888821550675718 and Generator Loss : 8.593352170377775
# Losses after iteration : 360 : Discriminator Loss : 1.180628601413622 and Generator Loss : 8.071740046335284
# Losses after iteration : 380 : Discriminator Loss : 1.3040900984818677 and Generator Loss : 8.582496217087815
# The model checkpoint has been saved !
# Losses after iteration : 400 : Discriminator Loss : 1.160393878906885 and Generator Loss : 8.951402723791599
# Losses after iteration : 420 : Discriminator Loss : 1.1878866913610524 and Generator Loss : 8.070426964119097
# Losses after iteration : 440 : Discriminator Loss : 1.1015216165568333 and Generator Loss : 8.339351351522993
# Losses after iteration : 460 : Discriminator Loss : 1.2036866907219026 and Generator Loss : 8.29911795049147
# Losses after iteration : 480 : Discriminator Loss : 1.1373059899247677 and Generator Loss : 8.688150824753505
# The model checkpoint has been saved !
# Losses after iteration : 500 : Discriminator Loss : 1.1516307208124783 and Generator Loss : 8.203497198150961
# Losses after iteration : 520 : Discriminator Loss : 1.182390048006999 and Generator Loss : 8.627515396005926
# Losses after iteration : 540 : Discriminator Loss : 1.2393521486702943 and Generator Loss : 8.351189813509219
# Losses after iteration : 560 : Discriminator Loss : 1.167898609504191 and Generator Loss : 8.239658526460037
# Losses after iteration : 580 : Discriminator Loss : 1.0865705451806091 and Generator Loss : 8.366709969764672
# The model checkpoint has been saved !
# Losses after iteration : 600 : Discriminator Loss : 1.1368865226152827 and Generator Loss : 8.224361400358934
# Losses after iteration : 620 : Discriminator Loss : 1.1714072512091307 and Generator Loss : 8.611375703134822
# Losses after iteration : 640 : Discriminator Loss : 1.212553992312415 and Generator Loss : 8.59807147685161
# Losses after iteration : 660 : Discriminator Loss : 1.1300984652807757 and Generator Loss : 8.216461104563248
# Losses after iteration : 680 : Discriminator Loss : 1.075543991245885 and Generator Loss : 8.2477677758969
# The model checkpoint has been saved !
# Losses after iteration : 700 : Discriminator Loss : 1.1322859721978766 and Generator Loss : 8.421321511728754
# Losses after iteration : 720 : Discriminator Loss : 1.1968298735300515 and Generator Loss : 8.374502570543779
# Losses after iteration : 740 : Discriminator Loss : 1.2736636735484652 and Generator Loss : 8.207172948721729
# Losses after iteration : 760 : Discriminator Loss : 1.1322788945018003 and Generator Loss : 8.412889241211474
# Losses after iteration : 780 : Discriminator Loss : 1.0855402940278163 and Generator Loss : 8.153851106584241
# The model checkpoint has been saved !
# Losses after iteration : 800 : Discriminator Loss : 1.1996599257155889 and Generator Loss : 8.316568355315937
# Losses after iteration : 820 : Discriminator Loss : 1.1873593493978276 and Generator Loss : 8.416644996670723
# Losses after iteration : 840 : Discriminator Loss : 1.0998282925054466 and Generator Loss : 8.116093372164817
# Losses after iteration : 860 : Discriminator Loss : 1.1454936273483352 and Generator Loss : 8.107469910831213
# Losses after iteration : 880 : Discriminator Loss : 1.1459042303382696 and Generator Loss : 8.19941403648952
# The model checkpoint has been saved !
# Losses after iteration : 900 : Discriminator Loss : 1.1535714896389135 and Generator Loss : 8.20984921425585
# Losses after iteration : 920 : Discriminator Loss : 1.2019691474523884 and Generator Loss : 8.702314874644848
# Losses after iteration : 940 : Discriminator Loss : 1.142587430370363 and Generator Loss : 8.092115025690441
# Losses after iteration : 960 : Discriminator Loss : 1.1174708183152862 and Generator Loss : 8.009645282658944
# Losses after iteration : 980 : Discriminator Loss : 1.1822255483729127 and Generator Loss : 7.846823071474191
# The model checkpoint has been saved !
# Losses after iteration : 1000 : Discriminator Loss : 1.1766942231551252 and Generator Loss : 8.344236015380796
# Losses after iteration : 1020 : Discriminator Loss : 1.1864783741464326 and Generator Loss : 7.939344334903259
# Losses after iteration : 1040 : Discriminator Loss : 1.1790069352653663 and Generator Loss : 8.38861151902504
# Losses after iteration : 1060 : Discriminator Loss : 1.1052888315995868 and Generator Loss : 8.23389236353293
# Losses after iteration : 1080 : Discriminator Loss : 1.2192042778574659 and Generator Loss : 7.9476908419301875
# The model checkpoint has been saved !
# Losses after iteration : 1100 : Discriminator Loss : 1.1160484400443038 and Generator Loss : 8.192431984620315
# Losses after iteration : 1120 : Discriminator Loss : 1.1363813758288202 and Generator Loss : 8.249995014916331
# Losses after iteration : 1140 : Discriminator Loss : 1.195242485447021 and Generator Loss : 8.145433203712525
# Losses after iteration : 1160 : Discriminator Loss : 1.138629474713552 and Generator Loss : 8.032364317525797
# Losses after iteration : 1180 : Discriminator Loss : 1.2108680995647774 and Generator Loss : 8.079626129240165
# The model checkpoint has been saved !
# Losses after iteration : 1200 : Discriminator Loss : 1.1451513168286531 and Generator Loss : 7.97581907350577
# Losses after iteration : 1220 : Discriminator Loss : 1.1696046523375778 and Generator Loss : 7.930989174372596
# Losses after iteration : 1240 : Discriminator Loss : 1.2441615616532475 and Generator Loss : 7.993088028301368
# Losses after iteration : 1260 : Discriminator Loss : 1.096026082217633 and Generator Loss : 8.491707478254805
# Losses after iteration : 1280 : Discriminator Loss : 1.1338578714458543 and Generator Loss : 7.841757271601194
# The model checkpoint has been saved !
# Losses after iteration : 1300 : Discriminator Loss : 1.1925926619163618 and Generator Loss : 8.082396934740341
# Losses after iteration : 1320 : Discriminator Loss : 1.1252959231865802 and Generator Loss : 7.783452873807461
# Losses after iteration : 1340 : Discriminator Loss : 1.20822768323583 and Generator Loss : 8.064231695361169
# Losses after iteration : 1360 : Discriminator Loss : 1.1177484796393622 and Generator Loss : 8.139355267620353
# Losses after iteration : 1380 : Discriminator Loss : 1.1835756232339334 and Generator Loss : 7.749347757654367
# The model checkpoint has been saved !
# Losses after iteration : 1400 : Discriminator Loss : 1.1617242591630155 and Generator Loss : 7.590590624496154
# Losses after iteration : 1420 : Discriminator Loss : 1.2774413049038973 and Generator Loss : 8.241654306413242
# Losses after iteration : 1440 : Discriminator Loss : 1.096905603825029 and Generator Loss : 8.066120207439946
# Losses after iteration : 1460 : Discriminator Loss : 1.1893357106641962 and Generator Loss : 8.093889574180258
# Losses after iteration : 1480 : Discriminator Loss : 1.1895962367702908 and Generator Loss : 7.718845236696197
# The model checkpoint has been saved !
# Losses after iteration : 1500 : Discriminator Loss : 1.1388244080674363 and Generator Loss : 7.769527525814665
# Losses after iteration : 1520 : Discriminator Loss : 1.2033896299996962 and Generator Loss : 7.883627774235772
# Losses after iteration : 1540 : Discriminator Loss : 1.1569274535375142 and Generator Loss : 7.927069996909471
# Losses after iteration : 1560 : Discriminator Loss : 1.1682111201728276 and Generator Loss : 8.159534471616789
# Losses after iteration : 1580 : Discriminator Loss : 1.1133043994272311 and Generator Loss : 7.561980355324657
# The model checkpoint has been saved !
# Losses after iteration : 1600 : Discriminator Loss : 1.168521391860479 and Generator Loss : 7.798851701098734
# Losses after iteration : 1620 : Discriminator Loss : 1.1969157560677914 and Generator Loss : 7.9625585664972025
# Losses after iteration : 1640 : Discriminator Loss : 1.152193929221149 and Generator Loss : 7.850925620913207
# Losses after iteration : 1660 : Discriminator Loss : 1.1319231828598333 and Generator Loss : 7.487466165477973
# Losses after iteration : 1680 : Discriminator Loss : 1.1583398902744615 and Generator Loss : 7.733818765412062
# The model checkpoint has been saved !
# Losses after iteration : 1700 : Discriminator Loss : 1.0909323638749608 and Generator Loss : 7.857281891026072
# Losses after iteration : 1720 : Discriminator Loss : 1.184347700791896 and Generator Loss : 7.86041247391169
# Losses after iteration : 1740 : Discriminator Loss : 1.3212179008863985 and Generator Loss : 7.563926019126524
# Losses after iteration : 1760 : Discriminator Loss : 1.13565509963187 and Generator Loss : 7.796350993579668
# Losses after iteration : 1780 : Discriminator Loss : 1.2055016580547797 and Generator Loss : 7.676007669291889
# The model checkpoint has been saved !
# Losses after iteration : 1800 : Discriminator Loss : 1.1355428975895727 and Generator Loss : 7.483398938019315
# Losses after iteration : 1820 : Discriminator Loss : 1.092659535676753 and Generator Loss : 7.5195820506210564
# Losses after iteration : 1840 : Discriminator Loss : 1.1096259454968427 and Generator Loss : 7.710251519400903
# Losses after iteration : 1860 : Discriminator Loss : 1.1919074989133602 and Generator Loss : 7.591604128056029
# Losses after iteration : 1880 : Discriminator Loss : 1.1610467161612585 and Generator Loss : 7.716390343819347
# The model checkpoint has been saved !
# Losses after iteration : 1900 : Discriminator Loss : 1.201304294749667 and Generator Loss : 7.326833693793065
# Losses after iteration : 1920 : Discriminator Loss : 1.0962782175273693 and Generator Loss : 7.737049043770004
# Losses after iteration : 1940 : Discriminator Loss : 1.2850430653145604 and Generator Loss : 7.570833260112922
# Losses after iteration : 1960 : Discriminator Loss : 1.1818995266747756 and Generator Loss : 7.431761398055511
# Losses after iteration : 1980 : Discriminator Loss : 1.1538733041039078 and Generator Loss : 7.843765649632772
# The model checkpoint has been saved !
# Losses after iteration : 2000 : Discriminator Loss : 1.1519191254377772 and Generator Loss : 7.761015869374445
# Losses after iteration : 2020 : Discriminator Loss : 1.1199613409810891 and Generator Loss : 7.69195331142772
# Losses after iteration : 2040 : Discriminator Loss : 1.0783344106009376 and Generator Loss : 7.523540891233421
# Losses after iteration : 2060 : Discriminator Loss : 1.1744745579211435 and Generator Loss : 7.616165161898065
# Losses after iteration : 2080 : Discriminator Loss : 1.2290909428636891 and Generator Loss : 7.008806758593882
# The model checkpoint has been saved !
# Losses after iteration : 2100 : Discriminator Loss : 1.1606008324310941 and Generator Loss : 7.465388364868967
# Losses after iteration : 2120 : Discriminator Loss : 1.0848076603537093 and Generator Loss : 7.470369178385373
# Losses after iteration : 2140 : Discriminator Loss : 1.211306987253288 and Generator Loss : 7.617756383094999
# Losses after iteration : 2160 : Discriminator Loss : 1.1256547677786397 and Generator Loss : 7.515405593342561
# Losses after iteration : 2180 : Discriminator Loss : 1.1181944084788196 and Generator Loss : 7.640173051635486
# The model checkpoint has been saved !
# Losses after iteration : 2200 : Discriminator Loss : 1.1713808083906736 and Generator Loss : 7.69949500299356
# Losses after iteration : 2220 : Discriminator Loss : 1.307871002225949 and Generator Loss : 7.600727726574091
# Losses after iteration : 2240 : Discriminator Loss : 1.1111377805711098 and Generator Loss : 7.706857127129017
# Losses after iteration : 2260 : Discriminator Loss : 1.2099787345587347 and Generator Loss : 7.253550023770411
# Losses after iteration : 2280 : Discriminator Loss : 1.0870378532045977 and Generator Loss : 7.556682544590376
# The model checkpoint has been saved !
# Losses after iteration : 2300 : Discriminator Loss : 1.0645348026114154 and Generator Loss : 7.919508857827971
# Losses after iteration : 2320 : Discriminator Loss : 1.1541902538795243 and Generator Loss : 7.289489089244187
# Losses after iteration : 2340 : Discriminator Loss : 1.1692956937618215 and Generator Loss : 7.765414657582764
# Losses after iteration : 2360 : Discriminator Loss : 1.1337456829379815 and Generator Loss : 7.433459321263444
# Losses after iteration : 2380 : Discriminator Loss : 1.1429323418096857 and Generator Loss : 7.395250557177351
# The model checkpoint has been saved !
# Losses after iteration : 2400 : Discriminator Loss : 1.0847214314985854 and Generator Loss : 7.816642067691828
# Losses after iteration : 2420 : Discriminator Loss : 1.2008013030683076 and Generator Loss : 7.649340726706312
# Losses after iteration : 2440 : Discriminator Loss : 1.1461791522327727 and Generator Loss : 7.991461359098103
# Losses after iteration : 2460 : Discriminator Loss : 1.3108283283223858 and Generator Loss : 7.364935761715626
# Losses after iteration : 2480 : Discriminator Loss : 1.1007567654956463 and Generator Loss : 7.056442319839472
# The model checkpoint has been saved !
# Losses after iteration : 2500 : Discriminator Loss : 1.1889872871660825 and Generator Loss : 7.263864369882349
# Losses after iteration : 2520 : Discriminator Loss : 1.156621808769454 and Generator Loss : 7.643862776914614
# Losses after iteration : 2540 : Discriminator Loss : 1.0787778838872752 and Generator Loss : 7.28591310761937
# Losses after iteration : 2560 : Discriminator Loss : 1.1520906896342773 and Generator Loss : 7.3641264292330835
# Losses after iteration : 2580 : Discriminator Loss : 1.113049676785668 and Generator Loss : 7.414946014339489
# The model checkpoint has been saved !
# Losses after iteration : 2600 : Discriminator Loss : 1.2203057253443668 and Generator Loss : 7.39444979733995
# Losses after iteration : 2620 : Discriminator Loss : 1.1802271132114743 and Generator Loss : 7.262923292539204
# Losses after iteration : 2640 : Discriminator Loss : 1.1547152349314014 and Generator Loss : 7.319724629718256
# Losses after iteration : 2660 : Discriminator Loss : 1.0927158631806528 and Generator Loss : 7.139531256409269
# Losses after iteration : 2680 : Discriminator Loss : 1.2240832299767248 and Generator Loss : 7.467354878997092
# The model checkpoint has been saved !
# Losses after iteration : 2700 : Discriminator Loss : 1.084539880130063 and Generator Loss : 7.386581604745821
# Losses after iteration : 2720 : Discriminator Loss : 1.297868378686989 and Generator Loss : 7.440874674663246
# Losses after iteration : 2740 : Discriminator Loss : 1.0851678786787562 and Generator Loss : 7.319615152266394
# Losses after iteration : 2760 : Discriminator Loss : 1.158600978520772 and Generator Loss : 7.545854541848752
# Losses after iteration : 2780 : Discriminator Loss : 1.1129069314433084 and Generator Loss : 7.033653730305929
# The model checkpoint has been saved !
# Losses after iteration : 2800 : Discriminator Loss : 1.041524087571976 and Generator Loss : 7.701922167841454
# Losses after iteration : 2820 : Discriminator Loss : 1.2577935341557036 and Generator Loss : 7.245131791671956
# Losses after iteration : 2840 : Discriminator Loss : 1.1738386569913226 and Generator Loss : 7.095730305414557
# Losses after iteration : 2860 : Discriminator Loss : 1.1305494859345053 and Generator Loss : 7.272668158048125
# Losses after iteration : 2880 : Discriminator Loss : 1.0641550610017572 and Generator Loss : 7.354074528257006
# The model checkpoint has been saved !
# Losses after iteration : 2900 : Discriminator Loss : 1.154050829286335 and Generator Loss : 7.374304697607544
# Losses after iteration : 2920 : Discriminator Loss : 1.1898407598194898 and Generator Loss : 7.491507618030968
# Losses after iteration : 2940 : Discriminator Loss : 1.1280057835887525 and Generator Loss : 7.317047774767978
# Losses after iteration : 2960 : Discriminator Loss : 1.1655030533141761 and Generator Loss : 7.250618476804325
# Losses after iteration : 2980 : Discriminator Loss : 1.1343694760638425 and Generator Loss : 7.009079336581955
# The model checkpoint has been saved !
# Losses after iteration : 3000 : Discriminator Loss : 1.0896985659427485 and Generator Loss : 7.384039603598144
# Losses after iteration : 3020 : Discriminator Loss : 1.1406427914676318 and Generator Loss : 7.0567754613233475
# Losses after iteration : 3040 : Discriminator Loss : 1.1964225982303769 and Generator Loss : 6.906061699265543
# Losses after iteration : 3060 : Discriminator Loss : 1.249306856624719 and Generator Loss : 7.260541633754092
# Losses after iteration : 3080 : Discriminator Loss : 1.1064890529706257 and Generator Loss : 7.205106315540908
# The model checkpoint has been saved !
# Losses after iteration : 3100 : Discriminator Loss : 1.1006818137573446 and Generator Loss : 7.48202915616819
# Losses after iteration : 3120 : Discriminator Loss : 1.1282343551306608 and Generator Loss : 7.365638950778576
# Losses after iteration : 3140 : Discriminator Loss : 1.1728395041865989 and Generator Loss : 7.3394434226545
# Losses after iteration : 3160 : Discriminator Loss : 1.1155213041675756 and Generator Loss : 6.986250469004467
# Losses after iteration : 3180 : Discriminator Loss : 1.2200668716266778 and Generator Loss : 7.138663428511556
# The model checkpoint has been saved !
# Losses after iteration : 3200 : Discriminator Loss : 1.078940207858824 and Generator Loss : 7.026344394679169
# Losses after iteration : 3220 : Discriminator Loss : 1.1476975500166973 and Generator Loss : 7.2077086150579905
# Losses after iteration : 3240 : Discriminator Loss : 1.1245093402784447 and Generator Loss : 7.482884260461084
# Losses after iteration : 3260 : Discriminator Loss : 1.1496881367163718 and Generator Loss : 7.140551574600465
# Losses after iteration : 3280 : Discriminator Loss : 1.172316570911123 and Generator Loss : 7.472915176816537
# The model checkpoint has been saved !
# Losses after iteration : 3300 : Discriminator Loss : 1.070694371597119 and Generator Loss : 7.180616700015035
# Losses after iteration : 3320 : Discriminator Loss : 1.1088600302327536 and Generator Loss : 7.217446677948277
# Losses after iteration : 3340 : Discriminator Loss : 1.165236373270889 and Generator Loss : 7.381226999056781
# Losses after iteration : 3360 : Discriminator Loss : 1.1807457516397428 and Generator Loss : 7.337491084624827
# Losses after iteration : 3380 : Discriminator Loss : 1.2026492983762578 and Generator Loss : 7.305078137323669
# The model checkpoint has been saved !
# Losses after iteration : 3400 : Discriminator Loss : 1.1147293147122999 and Generator Loss : 7.440425973248172
# Losses after iteration : 3420 : Discriminator Loss : 1.2313520797488324 and Generator Loss : 7.4807487016379195
# Losses after iteration : 3440 : Discriminator Loss : 1.097144200864123 and Generator Loss : 7.004988814113889
# Losses after iteration : 3460 : Discriminator Loss : 1.1273875997286695 and Generator Loss : 7.001747533079561
# Losses after iteration : 3480 : Discriminator Loss : 1.1665849663872347 and Generator Loss : 7.055293033560062
# The model checkpoint has been saved !
# Losses after iteration : 3500 : Discriminator Loss : 1.102149015955791 and Generator Loss : 7.293581945382989
# Losses after iteration : 3520 : Discriminator Loss : 1.141546512558588 and Generator Loss : 6.995272144689736
# Losses after iteration : 3540 : Discriminator Loss : 1.0825682338600693 and Generator Loss : 7.083223235462265
# Losses after iteration : 3560 : Discriminator Loss : 1.2021732277165103 and Generator Loss : 7.153596851452851
# Losses after iteration : 3580 : Discriminator Loss : 1.1003308720979788 and Generator Loss : 7.072725265350897
# The model checkpoint has been saved !
# Losses after iteration : 3600 : Discriminator Loss : 1.1761281405575124 and Generator Loss : 7.403363536186833
# Losses after iteration : 3620 : Discriminator Loss : 1.1359641921239731 and Generator Loss : 7.350202491585631
# Losses after iteration : 3640 : Discriminator Loss : 1.1148482564496556 and Generator Loss : 6.895952539135024
# Losses after iteration : 3660 : Discriminator Loss : 1.1080544579921956 and Generator Loss : 7.070783697743536
# Losses after iteration : 3680 : Discriminator Loss : 1.085325341318036 and Generator Loss : 7.159338395080357
# The model checkpoint has been saved !
# Losses after iteration : 3700 : Discriminator Loss : 1.247737888082556 and Generator Loss : 7.20271697996355
# Losses after iteration : 3720 : Discriminator Loss : 1.1592069008409833 and Generator Loss : 7.23762105230593
# Losses after iteration : 3740 : Discriminator Loss : 1.099586244601362 and Generator Loss : 7.065855023492131
# Losses after iteration : 3760 : Discriminator Loss : 1.1609209833546912 and Generator Loss : 6.813151702660882
# Losses after iteration : 3780 : Discriminator Loss : 1.1147617150050093 and Generator Loss : 6.486772475253123
# The model checkpoint has been saved !
# Losses after iteration : 3800 : Discriminator Loss : 1.1587240697483339 and Generator Loss : 7.03182671052776
# Losses after iteration : 3820 : Discriminator Loss : 1.077027893134232 and Generator Loss : 7.217934905266714
# Losses after iteration : 3840 : Discriminator Loss : 1.2001452176901 and Generator Loss : 6.890017733839089
# Losses after iteration : 3860 : Discriminator Loss : 1.0772953179399685 and Generator Loss : 7.045769093343585
# Losses after iteration : 3880 : Discriminator Loss : 1.0804739303422024 and Generator Loss : 7.176659435125288
# The model checkpoint has been saved !
# Losses after iteration : 3900 : Discriminator Loss : 1.091155066630103 and Generator Loss : 6.9759914648998915
# Losses after iteration : 3920 : Discriminator Loss : 1.1932305694502097 and Generator Loss : 7.063129505142756
# Losses after iteration : 3940 : Discriminator Loss : 1.0875728973448935 and Generator Loss : 7.096451681228376
# Losses after iteration : 3960 : Discriminator Loss : 1.133777729875526 and Generator Loss : 6.856126019641897
# Losses after iteration : 3980 : Discriminator Loss : 1.0637454150388883 and Generator Loss : 7.1619127004995775
# The model checkpoint has been saved !
# Losses after iteration : 4000 : Discriminator Loss : 1.1145871275659434 and Generator Loss : 7.162460718447237
# Losses after iteration : 4020 : Discriminator Loss : 1.0932762941201914 and Generator Loss : 7.235786710507639
# Losses after iteration : 4040 : Discriminator Loss : 1.1640041463215343 and Generator Loss : 6.875218465496462
# Losses after iteration : 4060 : Discriminator Loss : 1.055668125585794 and Generator Loss : 7.2127839320409874
# Losses after iteration : 4080 : Discriminator Loss : 1.1858494546233944 and Generator Loss : 7.234797326696753
# The model checkpoint has been saved !
# Losses after iteration : 4100 : Discriminator Loss : 1.1102380043705957 and Generator Loss : 7.110365173228102
# Losses after iteration : 4120 : Discriminator Loss : 1.1453522131160778 and Generator Loss : 6.998997094238334
# Losses after iteration : 4140 : Discriminator Loss : 1.17283297576573 and Generator Loss : 7.2829836221166975
# Losses after iteration : 4160 : Discriminator Loss : 1.0334784461521054 and Generator Loss : 6.842089181579373
# Losses after iteration : 4180 : Discriminator Loss : 1.1252159156256343 and Generator Loss : 7.036030219910609
# The model checkpoint has been saved !
# Losses after iteration : 4200 : Discriminator Loss : 1.1352097050316332 and Generator Loss : 6.957184291071196
# Losses after iteration : 4220 : Discriminator Loss : 1.1560144685851048 and Generator Loss : 7.031660632103014
# Losses after iteration : 4240 : Discriminator Loss : 1.0477835581857977 and Generator Loss : 7.144458719247446
# Losses after iteration : 4260 : Discriminator Loss : 1.0569078035700703 and Generator Loss : 7.168378530643349
# Losses after iteration : 4280 : Discriminator Loss : 1.13449007235652 and Generator Loss : 6.997856504808299
# The model checkpoint has been saved !
# Losses after iteration : 4300 : Discriminator Loss : 1.0448945861963534 and Generator Loss : 6.995037717703812
# Losses after iteration : 4320 : Discriminator Loss : 1.0699326500686792 and Generator Loss : 6.928309317912024
# Losses after iteration : 4340 : Discriminator Loss : 1.1048222405408035 and Generator Loss : 7.088831937051571
# Losses after iteration : 4360 : Discriminator Loss : 1.1002856516706208 and Generator Loss : 6.920301340507832
# Losses after iteration : 4380 : Discriminator Loss : 1.0972807758034802 and Generator Loss : 7.127109234558018
# The model checkpoint has been saved !
# Losses after iteration : 4400 : Discriminator Loss : 1.0997936611642045 and Generator Loss : 6.908751859209053
# Losses after iteration : 4420 : Discriminator Loss : 1.0684389118376891 and Generator Loss : 7.19096752555731
# Losses after iteration : 4440 : Discriminator Loss : 1.2774570701695007 and Generator Loss : 7.081532731061026
# Losses after iteration : 4460 : Discriminator Loss : 1.0983974080130885 and Generator Loss : 7.188235613385909
# Losses after iteration : 4480 : Discriminator Loss : 1.1189534401049226 and Generator Loss : 6.880427695531429
# The model checkpoint has been saved !
# Losses after iteration : 4500 : Discriminator Loss : 1.0689840113428954 and Generator Loss : 6.7350521421514316
# Losses after iteration : 4520 : Discriminator Loss : 1.1118773102339046 and Generator Loss : 6.881741528503251
# Losses after iteration : 4540 : Discriminator Loss : 1.036783437120265 and Generator Loss : 6.8260088449645435
# Losses after iteration : 4560 : Discriminator Loss : 1.1748124203512653 and Generator Loss : 6.960722181062989
# Losses after iteration : 4580 : Discriminator Loss : 1.068747584484019 and Generator Loss : 7.273243999894987
# The model checkpoint has been saved !
# Losses after iteration : 4600 : Discriminator Loss : 1.215287297138028 and Generator Loss : 6.983244472685657
# Losses after iteration : 4620 : Discriminator Loss : 1.107099097568702 and Generator Loss : 7.138033149412787
# Losses after iteration : 4640 : Discriminator Loss : 1.120309293293177 and Generator Loss : 6.605101924998637
# Losses after iteration : 4660 : Discriminator Loss : 1.1252750109479017 and Generator Loss : 6.707284357030497
# ([7.983951245908706,
#   8.842950530540321,
#   8.864234235289034,
#   8.849239966038054,
#   8.624198818874515,
#   8.854959778428116,
#   8.379893908203428,
#   8.891314742529246,
#   8.90380472844917,
#   8.726989512398168,
#   8.725664562005345,
#   8.603702788893841,
#   8.169645918125257,
#   8.575522025439897,
#   8.223437585831816,
#   8.295579713243173,
#   8.593352170377775,
#   8.071740046335284,
#   8.582496217087815,
#   8.951402723791599,
#   8.070426964119097,
#   8.339351351522993,
#   8.29911795049147,
#   8.688150824753505,
#   8.203497198150961,
#   8.627515396005926,
#   8.351189813509219,
#   8.239658526460037,
#   8.366709969764672,
#   8.224361400358934,
#   8.611375703134822,
#   8.59807147685161,
#   8.216461104563248,
#   8.2477677758969,
#   8.421321511728754,
#   8.374502570543779,
#   8.207172948721729,
#   8.412889241211474,
#   8.153851106584241,
#   8.316568355315937,
#   8.416644996670723,
#   8.116093372164817,
#   8.107469910831213,
#   8.19941403648952,
#   8.20984921425585,
#   8.702314874644848,
#   8.092115025690441,
#   8.009645282658944,
#   7.846823071474191,
#   8.344236015380796,
#   7.939344334903259,
#   8.38861151902504,
#   8.23389236353293,
#   7.9476908419301875,
#   8.192431984620315,
#   8.249995014916331,
#   8.145433203712525,
#   8.032364317525797,
#   8.079626129240165,
#   7.97581907350577,
#   7.930989174372596,
#   7.993088028301368,
#   8.491707478254805,
#   7.841757271601194,
#   8.082396934740341,
#   7.783452873807461,
#   8.064231695361169,
#   8.139355267620353,
#   7.749347757654367,
#   7.590590624496154,
#   8.241654306413242,
#   8.066120207439946,
#   8.093889574180258,
#   7.718845236696197,
#   7.769527525814665,
#   7.883627774235772,
#   7.927069996909471,
#   8.159534471616789,
#   7.561980355324657,
#   7.798851701098734,
#   7.9625585664972025,
#   7.850925620913207,
#   7.487466165477973,
#   7.733818765412062,
#   7.857281891026072,
#   7.86041247391169,
#   7.563926019126524,
#   7.796350993579668,
#   7.676007669291889,
#   7.483398938019315,
#   7.5195820506210564,
#   7.710251519400903,
#   7.591604128056029,
#   7.716390343819347,
#   7.326833693793065,
#   7.737049043770004,
#   7.570833260112922,
#   7.431761398055511,
#   7.843765649632772,
#   7.761015869374445,
#   7.69195331142772,
#   7.523540891233421,
#   7.616165161898065,
#   7.008806758593882,
#   7.465388364868967,
#   7.470369178385373,
#   7.617756383094999,
#   7.515405593342561,
#   7.640173051635486,
#   7.69949500299356,
#   7.600727726574091,
#   7.706857127129017,
#   7.253550023770411,
#   7.556682544590376,
#   7.919508857827971,
#   7.289489089244187,
#   7.765414657582764,
#   7.433459321263444,
#   7.395250557177351,
#   7.816642067691828,
#   7.649340726706312,
#   7.991461359098103,
#   7.364935761715626,
#   7.056442319839472,
#   7.263864369882349,
#   7.643862776914614,
#   7.28591310761937,
#   7.3641264292330835,
#   7.414946014339489,
#   7.39444979733995,
#   7.262923292539204,
#   7.319724629718256,
#   7.139531256409269,
#   7.467354878997092,
#   7.386581604745821,
#   7.440874674663246,
#   7.319615152266394,
#   7.545854541848752,
#   7.033653730305929,
#   7.701922167841454,
#   7.245131791671956,
#   7.095730305414557,
#   7.272668158048125,
#   7.354074528257006,
#   7.374304697607544,
#   7.491507618030968,
#   7.317047774767978,
#   7.250618476804325,
#   7.009079336581955,
#   7.384039603598144,
#   7.0567754613233475,
#   6.906061699265543,
#   7.260541633754092,
#   7.205106315540908,
#   7.48202915616819,
#   7.365638950778576,
#   7.3394434226545,
#   6.986250469004467,
#   7.138663428511556,
#   7.026344394679169,
#   7.2077086150579905,
#   7.482884260461084,
#   7.140551574600465,
#   7.472915176816537,
#   7.180616700015035,
#   7.217446677948277,
#   7.381226999056781,
#   7.337491084624827,
#   7.305078137323669,
#   7.440425973248172,
#   7.4807487016379195,
#   7.004988814113889,
#   7.001747533079561,
#   7.055293033560062,
#   7.293581945382989,
#   6.995272144689736,
#   7.083223235462265,
#   7.153596851452851,
#   7.072725265350897,
#   7.403363536186833,
#   7.350202491585631,
#   6.895952539135024,
#   7.070783697743536,
#   7.159338395080357,
#   7.20271697996355,
#   7.23762105230593,
#   7.065855023492131,
#   6.813151702660882,
#   6.486772475253123,
#   7.03182671052776,
#   7.217934905266714,
#   6.890017733839089,
#   7.045769093343585,
#   7.176659435125288,
#   6.9759914648998915,
#   7.063129505142756,
#   7.096451681228376,
#   6.856126019641897,
#   7.1619127004995775,
#   7.162460718447237,
#   7.235786710507639,
#   6.875218465496462,
#   7.2127839320409874,
#   7.234797326696753,
#   7.110365173228102,
#   6.998997094238334,
#   7.2829836221166975,
#   6.842089181579373,
#   7.036030219910609,
#   6.957184291071196,
#   7.031660632103014,
#   7.144458719247446,
#   7.168378530643349,
#   6.997856504808299,
#   6.995037717703812,
#   6.928309317912024,
#   7.088831937051571,
#   6.920301340507832,
#   7.127109234558018,
#   6.908751859209053,
#   7.19096752555731,
#   7.081532731061026,
#   7.188235613385909,
#   6.880427695531429,
#   6.7350521421514316,
#   6.881741528503251,
#   6.8260088449645435,
#   6.960722181062989,
#   7.273243999894987,
#   6.983244472685657,
#   7.138033149412787,
#   6.605101924998637,
#   6.707284357030497],
#  [1.1385328290710433,
#   1.1791269560896362,
#   1.141373723546566,
#   1.1533667138655503,
#   1.1529518249174844,
#   1.136410241502977,
#   1.2213811358704876,
#   1.2154852408543102,
#   1.1186936115611217,
#   1.2068840870363737,
#   1.070244209835716,
#   1.1886359660108128,
#   1.2232350206907143,
#   1.2149549029516928,
#   1.2426636477509667,
#   1.1446380844016246,
#   1.0888821550675718,
#   1.180628601413622,
#   1.3040900984818677,
#   1.160393878906885,
#   1.1878866913610524,
#   1.1015216165568333,
#   1.2036866907219026,
#   1.1373059899247677,
#   1.1516307208124783,
#   1.182390048006999,
#   1.2393521486702943,
#   1.167898609504191,
#   1.0865705451806091,
#   1.1368865226152827,
#   1.1714072512091307,
#   1.212553992312415,
#   1.1300984652807757,
#   1.075543991245885,
#   1.1322859721978766,
#   1.1968298735300515,
#   1.2736636735484652,
#   1.1322788945018003,
#   1.0855402940278163,
#   1.1996599257155889,
#   1.1873593493978276,
#   1.0998282925054466,
#   1.1454936273483352,
#   1.1459042303382696,
#   1.1535714896389135,
#   1.2019691474523884,
#   1.142587430370363,
#   1.1174708183152862,
#   1.1822255483729127,
#   1.1766942231551252,
#   1.1864783741464326,
#   1.1790069352653663,
#   1.1052888315995868,
#   1.2192042778574659,
#   1.1160484400443038,
#   1.1363813758288202,
#   1.195242485447021,
#   1.138629474713552,
#   1.2108680995647774,
#   1.1451513168286531,
#   1.1696046523375778,
#   1.2441615616532475,
#   1.096026082217633,
#   1.1338578714458543,
#   1.1925926619163618,
#   1.1252959231865802,
#   1.20822768323583,
#   1.1177484796393622,
#   1.1835756232339334,
#   1.1617242591630155,
#   1.2774413049038973,
#   1.096905603825029,
#   1.1893357106641962,
#   1.1895962367702908,
#   1.1388244080674363,
#   1.2033896299996962,
#   1.1569274535375142,
#   1.1682111201728276,
#   1.1133043994272311,
#   1.168521391860479,
#   1.1969157560677914,
#   1.152193929221149,
#   1.1319231828598333,
#   1.1583398902744615,
#   1.0909323638749608,
#   1.184347700791896,
#   1.3212179008863985,
#   1.13565509963187,
#   1.2055016580547797,
#   1.1355428975895727,
#   1.092659535676753,
#   1.1096259454968427,
#   1.1919074989133602,
#   1.1610467161612585,
#   1.201304294749667,
#   1.0962782175273693,
#   1.2850430653145604,
#   1.1818995266747756,
#   1.1538733041039078,
#   1.1519191254377772,
#   1.1199613409810891,
#   1.0783344106009376,
#   1.1744745579211435,
#   1.2290909428636891,
#   1.1606008324310941,
#   1.0848076603537093,
#   1.211306987253288,
#   1.1256547677786397,
#   1.1181944084788196,
#   1.1713808083906736,
#   1.307871002225949,
#   1.1111377805711098,
#   1.2099787345587347,
#   1.0870378532045977,
#   1.0645348026114154,
#   1.1541902538795243,
#   1.1692956937618215,
#   1.1337456829379815,
#   1.1429323418096857,
#   1.0847214314985854,
#   1.2008013030683076,
#   1.1461791522327727,
#   1.3108283283223858,
#   1.1007567654956463,
#   1.1889872871660825,
#   1.156621808769454,
#   1.0787778838872752,
#   1.1520906896342773,
#   1.113049676785668,
#   1.2203057253443668,
#   1.1802271132114743,
#   1.1547152349314014,
#   1.0927158631806528,
#   1.2240832299767248,
#   1.084539880130063,
#   1.297868378686989,
#   1.0851678786787562,
#   1.158600978520772,
#   1.1129069314433084,
#   1.041524087571976,
#   1.2577935341557036,
#   1.1738386569913226,
#   1.1305494859345053,
#   1.0641550610017572,
#   1.154050829286335,
#   1.1898407598194898,
#   1.1280057835887525,
#   1.1655030533141761,
#   1.1343694760638425,
#   1.0896985659427485,
#   1.1406427914676318,
#   1.1964225982303769,
#   1.249306856624719,
#   1.1064890529706257,
#   1.1006818137573446,
#   1.1282343551306608,
#   1.1728395041865989,
#   1.1155213041675756,
#   1.2200668716266778,
#   1.078940207858824,
#   1.1476975500166973,
#   1.1245093402784447,
#   1.1496881367163718,
#   1.172316570911123,
#   1.070694371597119,
#   1.1088600302327536,
#   1.165236373270889,
#   1.1807457516397428,
#   1.2026492983762578,
#   1.1147293147122999,
#   1.2313520797488324,
#   1.097144200864123,
#   1.1273875997286695,
#   1.1665849663872347,
#   1.102149015955791,
#   1.141546512558588,
#   1.0825682338600693,
#   1.2021732277165103,
#   1.1003308720979788,
#   1.1761281405575124,
#   1.1359641921239731,
#   1.1148482564496556,
#   1.1080544579921956,
#   1.085325341318036,
#   1.247737888082556,
#   1.1592069008409833,
#   1.099586244601362,
#   1.1609209833546912,
#   1.1147617150050093,
#   1.1587240697483339,
#   1.077027893134232,
#   1.2001452176901,
#   1.0772953179399685,
#   1.0804739303422024,
#   1.091155066630103,
#   1.1932305694502097,
#   1.0875728973448935,
#   1.133777729875526,
#   1.0637454150388883,
#   1.1145871275659434,
#   1.0932762941201914,
#   1.1640041463215343,
#   1.055668125585794,
#   1.1858494546233944,
#   1.1102380043705957,
#   1.1453522131160778,
#   1.17283297576573,
#   1.0334784461521054,
#   1.1252159156256343,
#   1.1352097050316332,
#   1.1560144685851048,
#   1.0477835581857977,
#   1.0569078035700703,
#   1.13449007235652,
#   1.0448945861963534,
#   1.0699326500686792,
#   1.1048222405408035,
#   1.1002856516706208,
#   1.0972807758034802,
#   1.0997936611642045,
#   1.0684389118376891,
#   1.2774570701695007,
#   1.0983974080130885,
#   1.1189534401049226,
#   1.0689840113428954,
#   1.1118773102339046,
#   1.036783437120265,
#   1.1748124203512653,
#   1.068747584484019,
#   1.215287297138028,
#   1.107099097568702,
#   1.120309293293177,
#   1.1252750109479017])

# %%
drive.flush_and_unmount()
